# %% [markdown]
# ## Anova Test

# %% [markdown]
# ### Do product categories have significantly different average order values?

# %%
import pandas as pd
from configs.settings import project_dir

# %%
p_dir = project_dir()
feature_dir = p_dir.FEATURE_ENGINEERED
cleaned_dir = p_dir.CLEANED_DIR

# %%
foi = feature_dir/'featured_order_items.csv'
fo = feature_dir/'featured_orders.csv'
fp = feature_dir/'featured_products.csv'

# %%
foi_df = pd.read_csv(foi,index_col=0)
fo_df = pd.read_csv(fo)
fp_df = pd.read_csv(fp)

# %%
foi_df.sample()
# Out:
#                                order_id  order_item_id  \
# 83361  bd5a6e9434ebae71399bef6eb45d85eb              1
#
#                              product_id                         seller_id  \
# 83361  a98a8d36f2c2f97f7d7c4c3222f2251c  c3867b4666c7d76867627c2f7fb22e21
#
#        shipping_limit_date  price  freight_value  total_amount  \
# 83361  2017-10-26 10:14:43  269.9          14.91        284.81
#
#        seller_revenue  seller_order_count
# 83361        42197.18                 259

# %%
fp_df.sample()
# Out:
#                              product_id  category_name  name_length  \
# 21625  3880d25d502b15b1de6fddc42ad1d67a  esporte_lazer         48.0
#
#        description_length  photos_qty  weight_g category_name_eng    volume
# 21625               562.0         5.0    9850.0    sports_leisure  183750.0

# %%
items_products = pd.merge(foi_df,fp_df,on='product_id',how='inner')

# %%
items_products.sample(4)
# Out:
#                                order_id  order_item_id  \
# 70905  a4101dff2487b4a3d89330b9fe480475              1
# 81120  baf664f0589b605f58b9e6630f0f267a              1
# 88017  cac00f6d5c47ea72c4a8f62a307edcda              1
# 84182  c1f534b2a0002528a5e5e5001f6be004              1
#
#                              product_id                         seller_id  \
# 70905  c1cf8f51eac90b1ff478250b3d35c37b  bc47d5d1490df2b36add65d733eafaba
# 81120  ffaf0af7eebb57c7f262b51ebb05dfd6  376d67b61dce0c990155286e7ae486a4
# 88017  cb9a231b86e78edf9802645824e0b2c1  8ca1551acf9832a4cf467bbbac15851f
# 84182  98a940d42d3ac029e40441023676ddfe  93dc87703c046b603023e75222018b45
#
#        shipping_limit_date  price  freight_value  total_amount  \
# 70905  2018-06-21 12:32:39   35.0          37.16         72.16
# 81120  2018-03-07 15:55:35   94.0          17.91        111.91
# 88017  2018-04-04 22:30:24  189.9          19.26        209.16
# ...

# %%
featured_df = pd.merge(items_products,fo_df,on='order_id',how='inner')

# %%
featured_df.sample(4)
# Out:
#                                 order_id  order_item_id  \
# 90775   d0ee2ae87e093d006aed295d79e325f4              2
# 21533   31ea9af161fd3c77c3c621aa178bcb34              1
# 100592  e794b6f8bc2c405d7a2038f44b32a5d9              1
# 86874   c8114f17241723311fd349c747e151b0              3
#
#                               product_id                         seller_id  \
# 90775   fa23bf270fb9880690b07d09b9f9ff20  1b8356dabde1d35e17cef975c3f82730
# 21533   1c21c1ed398eae61184065889ca3d4b0  a3e9a2c700480d9bb01fba070ba80a0e
# 100592  9ad75bd7267e5c724cb42c71ac56ca72  8160255418d5aaa7dbdc9f4c64ebda44
# 86874   d0fac709247e97e9b44a5351891ef9f3  7178f9f4dd81dcef02f62acdf8151e01
#
#         shipping_limit_date   price  freight_value  total_amount  \
# 90775   2017-07-11 22:50:07   59.99          16.18         76.17
# 21533   2018-02-08 03:10:35   69.00          17.73         86.73
# 100592  2018-03-21 12:49:09  105.90          23.32        129.22
# ...

# %%
from configs.database import engine

featured_df.to_sql('featured_df',engine,if_exists='replace',index=False)
# Out:
# -1
