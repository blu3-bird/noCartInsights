# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
from configs.settings import project_dir

# %%
p_dir = project_dir()

raw_data_dir =  p_dir.RAW_DATA_DIR

orders = raw_data_dir/'olist_orders_dataset.csv'
products = raw_data_dir/'olist_products_dataset.csv'
sellers = raw_data_dir/'olist_sellers_dataset.csv'
category = raw_data_dir /'product_category_name_translation.csv'

# %% [markdown]
# ## Orders table cleaning

# %%
orders_df = pd.read_csv(orders)
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 11682  065ac4b340bafd4f6bee041c63e10aef  9c29746c15ba972bc51e23fcdc498216
# 41975  df81dcb40098fb783a6525fa2f868bc9  749a270cfd211b20bea5c61663a99542
# 51183  5d008946b4867d5a4cbfb2b94d9e1496  ac4d8a51c24011ff9d9647013254d513
# 64692  4c5277b8c416e92df5b5b5b3882b4d58  7bba4420a869ab8dba1c7096358c1d66
# 73544  8821146ecf8a1eb441aa052b371f1814  6d41885118d1c89e00b8a67eb3e74653
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 11682    delivered      2017-06-02 12:37:27  2017-06-02 13:10:55
# 41975    delivered      2018-03-24 16:43:58  2018-03-24 16:56:07
# 51183    delivered      2017-03-03 09:10:02  2017-03-03 09:22:00
# 64692    delivered      2017-05-10 19:59:24  2017-05-10 20:05:14
# 73544    delivered      2018-08-11 08:47:48  2018-08-11 09:04:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 11682          2017-06-03 09:38:18           2017-06-13 17:29:55
# 41975          2018-04-16 13:54:53           2018-06-20 22:32:03
# 51183          2017-03-09 06:04:39           2017-03-10 09:45:32
# 64692          2017-05-11 10:09:25           2017-05-16 16:29:11
# 73544          2018-08-13 16:21:00           2018-08-15 16:26:52
#
#       order_estimated_delivery_date
# 11682           2017-06-27 00:00:00
# 41975           2018-05-04 00:00:00
# 51183           2017-03-22 00:00:00
# 64692           2017-05-30 00:00:00
# 73544           2018-08-16 00:00:00

# %%
print(orders_df.info())
print(orders_df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB
# None
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# fixing the date type columns
orders_df[['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_deliverey_date']] = orders_df[['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']].astype('datetime64[ns]')

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 26713  d77c01a7f1b1ea093949dbc6fe3cc2fa  2e4bda9c3b716e596451491497474dd3
# 5161   5ee7b62e53d3ff1201ab0f826ce413db  72adcf6a1e2e058550157b9ee9e202d8
# 86055  e7666f6bc0e98144ecc793ddbbdccc08  b0902450a721bbf06e520c99318a63a0
# 21158  d7511947889e0d0717a337554a6216ac  2d286468f438650339946ef48c13c971
# 87853  cf34fe44babb9fd001a001acfa43cabf  fe082a45e6e64db9443e39ef7e3d415a
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 26713    delivered      2018-04-25 17:25:13 2018-04-25 17:55:27
# 5161     delivered      2017-05-24 15:41:46 2017-05-24 15:55:10
# 86055    delivered      2018-01-23 14:58:44 2018-01-23 15:12:54
# 21158    delivered      2018-05-14 22:22:00 2018-05-14 22:37:50
# 87853    delivered      2017-11-06 18:36:52 2017-11-07 04:32:03
#
#       order_delivered_carrier_date order_delivered_customer_date  \
#
.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Products Dataset Cleaning

# %%
products_df = pd.read_csv(products)
products_df.sample(10)
# Out:
#                              product_id        product_category_name  \
# 10394  4ede085df4efad73e78ee270b669f7aa                 beleza_saude
# 23775  ecc224ec2ca908e1fdacf9aaad00fbe1                    papelaria
# 10875  652b2c3cfb3ca763c54795335a22f1ad                     pet_shop
# 28871  5b45b90d432972e54f815d543084e6ae                   brinquedos
# 5576   72a26085dd4fbd27f7206188081008d9        utilidades_domesticas
# 30570  b48946c4c9a1d7c81916522d00d6722f  fashion_bolsas_e_acessorios
# 76     278b3c6462e86b4556b99989513ddf73              eletroportateis
# 27505  02ca198b1084a6d8ed9e152d84243bfb                        bebes
# 8592   9d32095f76b97762307e86cfc18dd7a0              cama_mesa_banho
# 7188   b29c1749f99da888ea322a01420d5220     tablets_impressao_imagem
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 10394                 57.0                       656.0                 4.0
# 23775                 56.0                       456.0                 3.0
# 10875                 53.0                       468.0                 1.0
# 28871                 58.0                       423.0                 3.0
# 5576                  47.0                       587.0                 3.0
# 30570                 58.0                       392.0                 4.0
# 76                    58.0                       587.0                 3.0
# 27505                 58.0                       544.0                 3.0
# 8592                  38.0                       213.0                 2.0
# 7188                  60.0                      2532.0                 5.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 10394             605.0               34.0               13.0
# 23775           11950.0               18.0               46.0
# 10875             200.0               16.0                8.0
# 28871             400.0               18.0               14.0
# 5576             1000.0               28.0               12.0
# 30570              50.0               16.0                6.0
# 76                350.0               20.0               20.0
# 27505            2650.0               16.0               24.0
# 8592              400.0               25.0                9.0
# 7188             1100.0               30.0                5.0
#
#        product_width_cm
# 10394              11.0
# 23775              33.0
# 10875              15.0
# 28871              12.0
# 5576               21.0
# 30570              20.0
# 76                 20.0
# 27505              24.0
# 8592               19.0
# 7188               22.0

# %%
products_df.info()
# TO-DO : fix columns name
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32341 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 2.3 MB

# %%
products_df.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
products_df['product_category_name'].value_counts().to_string('../arson/product_category.csv') ## question to ask, why there are no NaN values in my arson folder of this query.
products_df[products_df['product_category_name'].isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# 128                    NaN                         NaN                 NaN
# 145                    NaN                         NaN                 NaN
# 154                    NaN                         NaN                 NaN
# 197                    NaN                         NaN                 NaN
# ...                    ...                         ...                 ...
# 32515                  NaN                         NaN                 NaN
# 32589                  NaN                         NaN                 NaN
# 32616                  NaN                         NaN                 NaN
# 32772                  NaN                         NaN                 NaN
# 32852                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 105               650.0               17.0               14.0
# 128               300.0               16.0                7.0
# 145               200.0               20.0               20.0
# 154             18500.0               41.0               30.0
# 197               300.0               35.0                7.0
# ...                 ...                ...                ...
# 32515            1800.0               30.0               20.0
# 32589             800.0               30.0               10.0
# 32616             200.0               21.0                8.0
# 32772            1300.0               45.0               16.0
# 32852             700.0               28.0                3.0
#
#        product_width_cm
# 105                12.0
# 128                20.0
# 145                20.0
# 154                41.0
# 197                12.0
# ...                 ...
# 32515              70.0
# 32589              23.0
# 32616              16.0
# 32772              45.0
# 32852              43.0
#
# [610 rows x 9 columns]

# %%
# dropping missing values. 
products_df = products_df.dropna()

# %%
print(products_df.shape)
products_df.isnull().sum()
# Out:
# (32340, 9)
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
products_df = products_df.rename(columns={
    'product_category_name': 'category_name',
    'product_name_lenght' : 'name_length',
    'product_description_lenght' : 'description_length',
    'product_photos_qty' : 'photos_qty',
    'product_weight_g' : 'weight_g',
    'product_length_cm' : 'length_cm',
    'product_height_cm' : 'height_cm',
    'product_width_cm' : 'width_cm'
})
products_df.sample(10)
# Out:
#                              product_id           category_name  name_length  \
# 22380  89197eee3abe531055b90c8ab1df05cc        moveis_decoracao         60.0
# 28846  ef7bac3fcd96b1f97400cb9cf17902d8              brinquedos         53.0
# 25573  cc3f2c3c98c34475aac4da902b2f7eee  informatica_acessorios         52.0
# 19247  0dc3bdb1240958ec9be2c91cba5bcc57   utilidades_domesticas         47.0
# 19734  d3a386ad58b99f0ddcc216ed9efb03c3         cama_mesa_banho         42.0
# 31420  dce3d94fd2f5d6d78c586d93faa33646        malas_acessorios         52.0
# 25082  06ecc3d4006ad6eb293a1b93ec3c7183        moveis_decoracao         59.0
# 11146  8f5501bc2a52a32cb42e220c855cd589                pet_shop         58.0
# 18416  af2808733a159ce5dfb2db7ec510f8d4   utilidades_domesticas         54.0
# 3212   de80c37c338574091896b7fdc81dc376            beleza_saude         49.0
#
#        description_length  photos_qty  weight_g  length_cm  height_cm  \
# 22380              1977.0         4.0    2800.0       69.0       11.0
# 28846              1329.0         7.0    4900.0       23.0       16.0
# 25573               181.0         1.0     100.0       40.0        2.0
# 19247               232.0         1.0     250.0       20.0        9.0
# 19734               702.0         1.0     840.0       22.0       15.0
# 31420               560.0         7.0     800.0       30.0       15.0
# 25082               903.0         1.0     750.0       22.0       22.0
# 11146              2357.0         6.0    2350.0       42.0       22.0
# 18416               641.0         1.0    1425.0       27.0       19.0
# 3212               1045.0         1.0     333.0       17.0       17.0
#
#        width_cm
# 22380      11.0
# 28846      31.0
# 25573      24.0
# 19247      12.0
# 19734      22.0
# 31420      15.0
# 25082      11.0
# 11146      32.0
# 18416      17.0
# 3212       15.0

# %% [markdown]
# ## Sellers Dataset cleaning

# %%
sellers_df = pd.read_csv(sellers)
sellers_df.sample(10)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 853   d7485b33791774c36108f8c69602d48d                   81020
# 980   f3862c2188522d89860c38a3ea8b550d                   14092
# 1883  4d8809767a5bafe22909c77951fb6b41                    6803
# 685   c03121937e54a93fcc1825c3098bbb6e                   82800
# 708   9b76ad3d04236f76bc71c59470305e13                   18550
# 491   8ff1a9df749e454105c55cda13e79143                   17509
# 2246  53b0300ca793f9834cd69c0678d35ee8                   13339
# 1568  94144541854e298c2d976cb893b81343                   94451
# 2916  80ceebb4ee9b31afb6c6a916a574a1e2                   86026
# 2302  f0ec78809fe0bc3edb11c9fe5b97b059                    4291
#
#          seller_city seller_state
# 853         curitiba           PR
# 980   ribeirao preto           SP
# 1883  embu das artes           SP
# 685         curitiba           PR
# 708          boituva           SP
# 491          marilia           SP
# 2246      indaiatuba           SP
# 1568          viamao           RS
# 2916        londrina           PR
# 2302       sao paulo           SP

# %%
sellers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   str
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   str
#  3   seller_state            3095 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 96.8 KB

# %%
sellers_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers_df.groupby('seller_city')[['seller_state','seller_zip_code_prefix']].value_counts().to_string('../arson/sellers_state.csv')

# %%
# Question to ask: how to handle the invalid values in sellers_city columns
