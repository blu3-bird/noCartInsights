# %% [markdown]
# ## Applying Feature Engineering on our dataset

# %%
import pandas as pd
import numpy as np
from configs.settings import project_dir

# %%
p_dir = project_dir()
clean_data_dir = p_dir.CLEANED_DIR

category_name = clean_data_dir/'category_name.csv'
customers = clean_data_dir/'clean_customers.csv'
location = clean_data_dir/'cleaned_location.csv'
order_payments = clean_data_dir/'cleaned_order_payments.csv'
orders_items = clean_data_dir/'cleaned_orders_items.csv'
order_reviews = clean_data_dir/'cleaned_order_reviews.csv'
orders = clean_data_dir/'cleaned_orders.csv'
products = clean_data_dir/'cleaned_products.csv'
sellers = clean_data_dir/'cleaned_sellers.csv'

# %%
orders_df = pd.read_csv(orders)
orders_df = orders_df.drop('Unnamed: 0',axis=1)
orders_df.sample(5)

payments_df = pd.read_csv(order_payments)
payments_df = payments_df.drop('Unnamed: 0',axis=1)
payments_df.sample(5)

orders_items_df = pd.read_csv(orders_items)
orders_items_df = orders_items_df.drop('Unnamed: 0',axis=1)
orders_items_df.sample(5)
# Out:
#                                order_id  order_item_id  \
# 54794  7c9524b31589e9c6c9d84d17bc07a966              1
# 45387  672260490e5b2772766e523be71a3a9b              2
# 23295  351d5d1e18d0b2bc2024ff1655911dd1              1
# 98177  deafd5190946c25dcce1974055abb693              1
# 36949  53e9eddc6f35cac865b535ed8868d5e3              1
#
#                              product_id                         seller_id  \
# 54794  497f3cf6e1c584b489ca78da2bc08d5a  b1a81260566c1bac3114a6d124413f27
# 45387  88bd8458fdc2ceec3e71ef1d867a7b45  92eb0f42c21942b6552362b9b114707d
# 23295  5d7c23067ed3fc8c6e699b9373d5890b  6560211a19b47992c3666cc44a7e94c0
# 98177  642a40d4d73b4b2604968937de13634a  d2374cbcbb3ca4ab1086534108cc3ab7
# 36949  461f43be3bdf8844e65b62d9ac2c7a5a  b33e7c55446eabf8fe1a42d037ac7d6d
#
#        shipping_limit_date  price  freight_value
# 54794  2018-05-17 12:31:35  129.9          19.88
# 45387  2017-07-19 22:55:14   13.5          30.76
# 23295  2018-06-11 03:31:04   49.0          22.85
# 98177  2017-07-20 03:15:27   12.9          11.85
# 36949  2017-11-28 22:36:21  146.0          15.77

# %%
orders_items_df.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
## Creating a new columns of total amount of by doing sum of price and fright value
orders_items_df['total_amount'] = orders_items_df['price'] + orders_items_df['freight_value']

# %%
orders_items_df.sample(5)
# Out:
#                                order_id  order_item_id  \
# 98613  dfa3653e86520b99a8a2dceed4362a7c              2
# 11194  1973095f2596945f9dcc773608d8cad2              1
# 40428  5c08ed25ee3f139b35a21c0c12944802              5
# 93824  d4a72eff3bfdb6ff7667bef4119283e9              2
# 26864  3d1b89c754a150dde1beea6f7577dcd4              2
#
#                              product_id                         seller_id  \
# 98613  1a428b685ede76217c9efb550c4aaa59  d2374cbcbb3ca4ab1086534108cc3ab7
# 11194  242edc6b84c00f0d48c664a020a92c52  6cd68b3ed6d59aaa9fece558ad360c0a
# 40428  cf1d8e226162a1d0ad61f29b7ed72d82  7d456afc660226829370f3173d14520c
# 93824  a3309868978f986b3865b8a3729192e2  7ad32824caee82087b3e2e5f33b1bf32
# 26864  f337ef897cbb898bf66be49d94c0bba8  1dfe5347016252a7884b694d4f10f5c4
#
#        shipping_limit_date  price  freight_value  total_amount
# 98613  2017-07-10 10:33:38   22.9          11.85         34.75
# 11194  2017-02-12 21:42:21   54.9          14.14         69.04
# 40428  2018-02-13 12:15:29   30.0          14.10         44.10
# 93824  2018-07-06 01:31:04   37.0          19.45         56.45
# 26864  2018-04-04 22:55:18   60.0          19.39         79.39

# %%
orders_df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_estimated_deliverey_date'],
#       dtype='str')

# %%
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   order_id                        99441 non-null  str
#  1   customer_id                     99441 non-null  str
#  2   order_status                    99441 non-null  str
#  3   order_purchase_timestamp        99441 non-null  str
#  4   order_approved_at               99281 non-null  str
#  5   order_delivered_carrier_date    97658 non-null  str
#  6   order_delivered_customer_date   96476 non-null  str
#  7   order_estimated_delivery_date   99441 non-null  str
#  8   order_estimated_deliverey_date  99441 non-null  str
# dtypes: str(9)
# memory usage: 6.8 MB

# %%
# fixing the dtype
date_col = [
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]

for col in date_col:
    orders_df[col] = pd.to_datetime(orders_df[col])

# %%
orders_df = orders_df.drop('order_estimated_deliverey_date',axis=1)

# %%
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  datetime64[us]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[us]
#  6   order_delivered_customer_date  96476 non-null  datetime64[us]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[us]
# dtypes: datetime64[us](4), str(4)
# memory usage: 6.1 MB

# %%
# creating a new columns in orders_df delivery_days usig order_purchase_timestamp and order_delivered-customer_date
orders_df = orders_df.rename(
    columns={
        'order_purchase_timestamp' : 'order_purchase',
        'order_approved_at' : 'approved_at',
        'order_delivered_carrier_date' : 'delivered_carrier_date',
        'order_delivered_customer_date' : 'delivered_customer_date',
        'order_estimated_delivery_date' : 'estimated_delivery_date'
    }
)



orders_df['delivery_days'] = (orders_df['delivered_customer_date'] - orders_df['approved_at']).dt.days
# orders_df.sample(5)

# %%
# adding a new columns delivery_delay

orders_df ['delivery_delay_days'] = (orders_df['delivered_customer_date'] - orders_df['estimated_delivery_date']).dt.days

# orders_df = orders_df.drop('delivery_delay',axis=1)

# adding a new columns is_delayed 
orders_df['is_delayed'] = (orders_df['estimated_delivery_date'] < orders_df['delivered_customer_date']).astype(int)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 76462  fbdb43f2551a3acd3d9ac5e2ddf92080  40224de178a0923de5998a578a19766c
# 930    1133f2dfc033ba92bf6c470b20f6f332  e583c743a5c26e0870b08e4e6efeac7f
# 441    faa911f9ff46e53aedc9408c5d6a24ad  77dccd21b005b20fc1f1418c979ca354
# 20401  54243ef50fa7c7f650224a26f43bb90c  9992dd6e05230ed6258a1e7fd24d34dc
# 30586  5f9500d487e1ab13436ab55d3b1c27d6  7d9f40a95248706df2f0f8f2406fe759
#
#       order_status       order_purchase         approved_at  \
# 76462    delivered  2018-08-16 14:09:10 2018-08-17 14:35:20
# 930      delivered  2018-05-21 13:31:41 2018-05-22 07:55:10
# 441      delivered  2018-03-07 16:42:57 2018-03-07 17:20:24
# 20401    delivered  2018-07-01 12:18:03 2018-07-01 12:30:13
# 30586    delivered  2017-10-08 16:34:44 2017-10-08 16:49:19
#
#       delivered_carrier_date delivered_customer_date estimated_delivery_date  \
# 76462    2018-08-20 07:53:00     2018-08-23 18:07:22              2018-09-11
# 930      2018-05-22 13:15:00     2018-06-08 18:48:24              2018-06-14
# 441      2018-03-12 23:22:04     2018-03-18 17:17:03              2018-04-04
# 20401    2018-07-03 12:22:00     2018-07-11 23:32:44              2018-08-03
# 30586    2017-10-09 20:21:27     2017-10-31 19:17:07              2017-11-09
#
#        delivery_days  delivery_delay_days  is_delayed
# 76462            6.0                -19.0           0
# 930             17.0                 -6.0           0
# 441             10.0                -17.0           0
# 20401           10.0                -23.0           0
# 30586           23.0                 -9.0           0

# %%
customers_df = pd.read_csv(customers,index_col=0)
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 5 columns]

# %%
# merging customers and orders tables
orders_df = orders_df.merge(
    customers_df[['customer_id','customer_unique_id']],
    on='customer_id',
    how='left'
)

orders_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders_df['customer_order_count'] =orders_df.groupby('customer_unique_id')['order_id'].transform('count')

# %%
orders_df['customer_order_count'].value_counts()

# adding bool columns bout is it a repeat customer
orders_df['is_repeat_customer'] = (orders_df['customer_order_count'] > 1).astype(int)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 11208  94fd9673a19164ebf42ba85826aff8b4  bd5a96b05e3979db414986300a0ca0a6
# 33893  ca70cf8792727da384ba1b6e384cfbf6  2a0fac767e1db2a693c798963e7a597a
# 35335  f5c1da9aba0b0b41ec20f6771bfd060a  55cf037bf8aab8f9546a9ef52eade642
# 89705  e6135c8e8606487b103a6835a5c429ff  eb8fa9d9b120b9368060017e95e085c6
# 78373  423a4ec1579258ccf1267d7414246c52  1388eca3c7f75f6038c0d636f9f3b2ca
#
#       order_status       order_purchase         approved_at  \
# 11208    delivered  2018-05-24 10:43:56 2018-05-24 10:59:32
# 33893    delivered  2018-06-07 22:42:55 2018-06-07 23:13:56
# 35335    delivered  2018-07-16 21:51:51 2018-07-18 02:55:22
# 89705    delivered  2017-12-08 20:17:30 2017-12-08 20:30:57
# 78373    delivered  2017-06-06 23:09:15 2017-06-07 14:25:22
#
#       delivered_carrier_date delivered_customer_date estimated_delivery_date  \
# 11208    2018-05-24 14:24:00     2018-05-25 20:17:42              2018-06-11
# 33893    2018-06-20 14:09:00     2018-06-25 21:42:28              2018-07-27
# 35335    2018-07-18 14:10:00     2018-07-23 20:42:17              2018-07-30
# 89705    2017-12-12 23:53:16     2017-12-28 20:34:20              2018-01-09
# 78373    2017-06-09 09:21:33     2017-06-19 19:58:28              2017-07-03
#
#        delivery_days  delivery_delay_days  is_delayed  \
# 11208            1.0                -17.0           0
# 33893           17.0                -32.0           0
# 35335            5.0                 -7.0           0
# 89705           20.0                -12.0           0
# 78373           12.0                -14.0           0
#
#                      customer_unique_id  customer_order_count  \
# 11208  84ad9aa5281382be243bc17661907793                     1
# 33893  2f2f4b5a5700a5b108e6da7f0f5f5bb3                     2
# 35335  fbad662de6e9d6dec30dac3a946e05b3                     1
# 89705  f2338b63241a7ff941080e0d5e4b4b80                     1
# 78373  ae52fa61f27bd494a25bc4c101fa29d0                     2
#
#        is_repeat_customer
# 11208                   0
# 33893                   1
# 35335                   0
# 89705                   0
# 78373                   1

# %%
# total spending per customer

orders_df.groupby('customer_unique_id')['order_id'].transform('count')
# Out:
# 0        2
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 99436    1
# 99437    1
# 99438    1
# 99439    1
# 99440    1
# Name: order_id, Length: 99441, dtype: int64

# %%
feature_engineered_path = p_dir.FEATURE_ENGINEERED

orders_df.to_csv(feature_engineered_path/'featured_orders.csv',index=False)

# %% [markdown]
# #####  merging the products and category_name tables on category name col

# %%
products_df = pd.read_csv(products,index_col=0)
products_df.sample(5)

category_name_df = pd.read_csv(category_name,index_col=0)
category_name_df = category_name_df.rename(columns={
    'product_category_name':'category_name',
    'product_category_name_english' : 'category_name_eng'
})
category_name_df.sample()
# Out:
#          category_name category_name_eng
# 16  ferramentas_jardim      garden_tools

# %%
products_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
products_df = products_df.merge(
    category_name_df[['category_name','category_name_eng']],
    on='category_name',
    how='left'
)

products_df.sample(5)
# Out:
#                              product_id           category_name  name_length  \
# 15228  b09695c98d949d39cea25c5abb049fa8  informatica_acessorios         59.0
# 6859   d66815037fba03ebe1e3bcb9967723aa              brinquedos         46.0
# 4651   b596e2d70dd2f5fb5ff9ee2a1c803e5b           esporte_lazer         53.0
# 6284   ca3d8213acc967dd4e7c85c05406f71f              perfumaria         47.0
# 18545  c3b9c5a3a88d5cd18800fb865741d9ad         cama_mesa_banho         47.0
#
#        description_length  photos_qty  weight_g  length_cm  height_cm  \
# 15228               149.0         2.0     450.0       20.0       15.0
# 6859                853.0         3.0    1349.0       35.0       49.0
# 4651                748.0         2.0    6300.0       42.0       20.0
# 6284                159.0         1.0     390.0       22.0       11.0
# 18545               162.0         3.0    2800.0       35.0       12.0
#
#        width_cm      category_name_eng
# 15228      16.0  computers_accessories
# 6859       25.0                   toys
# 4651       32.0         sports_leisure
# 6284       16.0              perfumery
# 18545      30.0         bed_bath_table

# %%
products_df['volume'] = (products_df['length_cm'] * products_df['width_cm'] * products_df['height_cm'])

# %%
products_df = products_df.drop(['length_cm','width_cm','height_cm'],axis=1)
products_df.sample(5)
# Out:
#                              product_id             category_name  \
# 9747   b250756c5f34998033b1811801686a0c     utilidades_domesticas
# 23654  f1261761d91b574288d60a6390a007b6           cama_mesa_banho
# 20780  ab0a97f604550b5b5b99180a6dc04461  tablets_impressao_imagem
# 18112  5abf8ac7fdb8291904445c4bd64ac917          malas_acessorios
# 5759   0a8038344359ff23c26156650b801e6c        ferramentas_jardim
#
#        name_length  description_length  photos_qty  weight_g  \
# 9747          26.0               330.0         2.0    1840.0
# 23654         64.0               332.0         1.0    1600.0
# 20780         34.0               150.0         1.0     150.0
# 18112         55.0               596.0         2.0    4200.0
# 5759          48.0               916.0         1.0    1600.0
#
#             category_name_eng   volume
# 9747               housewares  15480.0
# 23654          bed_bath_table  23625.0
# 20780  tablets_printing_image   7260.0
# 18112     luggage_accessories  50875.0
# 5759             garden_tools   9408.0

# %%
products_df.columns
# Out:
# Index(['product_id', 'category_name', 'name_length', 'description_length',
#        'photos_qty', 'weight_g', 'length_cm', 'height_cm', 'width_cm',
#        'category_name_eng', 'volume'],
#       dtype='str')

# %%
products_df.to_csv(feature_engineered_path/'featured_products.csv',index=0)

# %% [markdown]
# #### total spending by per customer

# %%
print(orders_items_df.sample(1))
# customers_df.sample(3)
# payments_df.sample(4)
orders_df.sample(4)
# Out:
#                                order_id  order_item_id  \
# 35773  50fe82ce977520094518dd8618d7331a              1
#
#                              product_id                         seller_id  \
# 35773  d245838e3d0b2b51d751ccdc98885a8e  cc419e0650a3c5ba77189a1882b7556a
#
#        shipping_limit_date  price  freight_value  total_amount
# 35773  2018-05-28 18:54:28    6.0           7.39         13.39
#                                order_id                       customer_id  \
# 79108  ed2fd29485ba0cce066d8a1e5fcd8bbc  c30d6ff9e2fca6659a28c1c9e89ef661
# 19337  689c69f5d10d806b64b4b89bf4a7e5e1  64278a2a437f6648a76a81c25eecda28
# 91877  9d7f2c9f33008498700ffdc3162878fb  4d54bd3326ad77cbe4e1bd929a209106
# 70387  9f59586295a7d2e6c788a21e6cf5d8a9  87ba7b183e6455c57728e6b2520f85a3
#
#       order_status       order_purchase         approved_at  \
# 79108    delivered  2018-01-22 18:27:32 2018-01-22 18:36:28
# 19337    delivered  2017-11-21 11:05:07 2017-11-21 11:31:28
# 91877    delivered  2017-08-27 13:02:01 2017-08-27 13:15:16
# 70387    delivered  2017-07-13 00:18:47 2017-07-14 00:25:17
#
#       delivered_carrier_date delivered_customer_date estimated_delivery_date  \
# 79108    2018-01-24 11:02:38     2018-01-25 23:49:14              2018-02-14
# 19337    2017-11-23 23:26:52     2017-12-05 22:33:25              2017-12-11
# 91877    2017-08-28 19:03:48     2017-08-31 21:00:31              2017-09-18
# 70387    2017-07-14 17:33:59     2017-07-20 19:27:51              2017-08-10
#
#        delivery_days  delivery_delay_days  is_delayed  \
# 79108            3.0                -20.0           0
# 19337           14.0                 -6.0           0
# 91877            4.0                -18.0           0
# 70387            6.0                -21.0           0
#
#                      customer_unique_id  customer_order_count  \
# 79108  786c1bc3f7883dc7f01fb86aef168692                     1
# 19337  f2753e6f137566064d382a6136495948                     1
# 91877  080fe35c7d6d30f7b519fce853438380                     1
# 70387  06445b7b84f41be019bb45a23c972b6d                     1
#
#        is_repeat_customer
# 79108                   0
# 19337                   0
# 91877                   0
# 70387                   0

# %%
# joining the orders_df and orders_items_df on order_id

orders_df = orders_df.merge(
    orders_items_df[['order_id','total_amount']],
    on='order_id',
    how='left'
)

# %%
orders_df.sample(2)
# Out:
#                                order_id                       customer_id  \
# 89801  dd359d3c294458c6d642b2eea9212bf5  5c58d1ea5a893380ecdd96dd6dfd5ec5
# 12160  87b732d9778eda3d298cbd97c22aba48  a0508b86d745112acd8e2ac4a1c3b02a
#
#       order_status       order_purchase         approved_at  \
# 89801     invoiced  2016-10-04 13:02:10 2016-10-05 03:08:27
# 12160     invoiced  2018-03-09 12:08:02 2018-03-10 03:35:43
#
#       delivered_carrier_date delivered_customer_date estimated_delivery_date  \
# 89801                    NaT                     NaT              2016-11-24
# 12160                    NaT                     NaT              2018-04-19
#
#        delivery_days  delivery_delay_days  is_delayed  \
# 89801            NaN                  NaN           0
# 12160            NaN                  NaN           0
#
#                      customer_unique_id  customer_order_count  \
# 89801  2ad9e4ed11e15401527b7e30080ce45f                     1
# 12160  90a4155ff741f30c5321018d12d4b43e                     1
#
#        is_repeat_customer  total_amount
# 89801                   0        177.20
# 12160                   0        256.47

# %%
orders_df['total_spending_by_cust'] = (orders_df.groupby('customer_unique_id')['total_amount'].transform('sum'))

# %%
orders_df.sample(5)
# Out:
#                                 order_id                       customer_id  \
# 94512   cec16bf8607acd5483286d4a74fb4365  06133ba8a78671888d881e2e5f35597d
# 21938   6c122d18e485014d7f23bd0093465404  303f121f379bb6c560b404054afe6e60
# 110397  0ba4b12916fc52234012c61ed7ebce94  73e1d8182bdefebf6613a9b73abb0505
# 67455   d5cb12269711bd1eaf7eed8fd32a7c95  f1622b5b691cbc9c39f10ff359043335
# 51687   a65f614a7b51b56f47bb90f4d9fdf16f  1ffd3a384c97afd38617f8887a8cc035
#
#        order_status       order_purchase         approved_at  \
# 94512     delivered  2017-11-24 21:13:26 2017-11-24 23:59:35
# 21938     delivered  2017-09-03 21:28:15 2017-09-03 21:44:17
# 110397    delivered  2017-10-19 23:03:56 2017-10-19 23:26:29
# 67455     delivered  2018-05-14 17:00:31 2018-05-15 17:37:52
# 51687     delivered  2017-07-07 17:43:26 2017-07-07 17:55:22
#
#        delivered_carrier_date delivered_customer_date estimated_delivery_date  \
# 94512     2017-11-29 21:32:03     2017-12-07 19:15:06              2017-12-18
# 21938     2017-09-04 20:34:56     2017-09-11 18:17:50              2017-09-25
# 110397    2017-10-20 18:32:11     2017-10-26 20:22:14              2017-11-07
# 67455     2018-05-16 13:36:00     2018-05-18 17:12:51              2018-05-29
# 51687     2017-07-18 22:47:03     2017-07-20 21:00:04              2017-07-20
#
#         delivery_days  delivery_delay_days  is_delayed  \
# 94512            12.0                -11.0           0
# 21938             7.0                -14.0           0
# 110397            6.0                -12.0           0
# 67455             2.0                -11.0           0
# 51687            13.0                  0.0           1
#
#                       customer_unique_id  customer_order_count  \
# 94512   a0f0a2082b269a9715ba874c94b592f3                     2
# 21938   ae207cf8119fd10e3b9ac24570089fad                     2
# 110397  ac94b0426cf12741dbd4c0138a2afa73                     1
# 67455   d58f7cb9d4f025430011a96c1a7c1c7d                     1
# 51687   d700a290654faef414da173a6aba5acf                     1
#
#         is_repeat_customer  total_amount  total_spending_by_cust
# 94512                    1         90.18                  492.74
# 21938                    1        131.41                  281.50
# 110397                   0         46.92                  135.51
# 67455                    0         42.78                   42.78
# 51687                    0         26.77                   26.77

# %%
sellers_df = pd.read_csv(sellers,index_col=0)
sellers_df.sample(5)
sellers_df['seller_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders_items_df.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'total_amount'],
#       dtype='str')

# %%
# total revenue by each seller 

orders_items_df.sample(5)
orders_items_df['seller_revenue'] = (orders_items_df.groupby('seller_id')['total_amount']).transform('sum')

# %%
# seller order count
orders_items_df['seller_order_count'] = (orders_items_df.groupby('seller_id')['product_id']).transform('count')

# %%
orders_items_df.sample(3)
# Out:
#                                order_id  order_item_id  \
# 17479  2811a528a7b5ae1d207e9620a4c6b44b              1
# 8613   13b1842c7e0b9a22f8787450f137e66e              1
# 29846  43dad3b15826adef6cba40d7aab778d7              1
#
#                              product_id                         seller_id  \
# 17479  d7aac623b37a602920a230c0bfd96025  a44fb5a447105f8469bdf16bf9159f25
# 8613   58f1f70c378b16f78eff44c7104aa772  3f3486b61f45078d4f31ee5e43d8c5bb
# 29846  eb31436580a610f202c859463d8c7415  06e5eefc71ec47ae763c5c6f8db7064f
#
#        shipping_limit_date   price  freight_value  total_amount  \
# 17479  2018-08-02 08:55:21   39.90          18.38         58.28
# 8613   2018-02-21 13:31:19  139.99          16.74        156.73
# 29846  2018-06-28 13:30:46  226.18          19.68        245.86
#
#        seller_revenue  seller_order_count
# 17479         4292.71                  19
# 8613          4726.57                  40
# 29846        24381.84                  95

# %%
orders_items_df.to_csv(feature_engineered_path/'featured_order_items.csv')
